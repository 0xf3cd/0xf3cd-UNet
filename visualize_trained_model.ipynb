# %%
from visualize import *

# %%
# mdir = 'origin_unet_642020-06-11-Jun-1591864348'
# mdir = 'octonly_unet_642020-06-03-Jun-1591168924'
# mdir = 'att_unet_642020-06-01-Jun-1591031727'
# mdir = 'octatt_unet_642020-06-02-Jun-1591089164'
mdir = 'octatt_unet_642020-06-11-Jun-1591869770'
model = load_trained_model(mdir)
# Out:
# /root/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/core.py:901: UserWarning: model is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512, 512, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
test_d = get_test_data(togray=True)
test_d_rgb = get_test_data(togray=False)

mask_d = get_mask_data(togray=True)
mask_d_rgb = get_mask_data(togray=False)

# use model to perform prediction on test_d
pred_d = get_pred_results(model)
save_pred_results(mdir, pred_d)

# load previously-predicted pictures
pred_d = load_prev_pred_results(mdir, togray=True)
pred_d_rgb = load_prev_pred_results(mdir, togray=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b029d6d7fe91> in <module>
#       6
#       7 # use model to perform prediction on test_d
# ----> 8 pred_d = get_pred_results(model)
#       9 save_pred_results(mdir, pred_d)
#      10
#
# <ipython-input-14-eb253d710273> in get_pred_results(model)
#       1 def get_pred_results(model):
#       2     test_gen = test_generator(test_files, target_size=(pic_size,pic_size))
# ----> 3     results = model.predict(test_gen, len(test_files), verbose=1)
#       4     return results[:,:,:,0]
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     907         max_queue_size=max_queue_size,
#     908         workers=workers,
# ...

# %%
show_acc_loss_dice_iou(mdir)
show_acc_loss_dice_iou_fig(mdir)

# %%
show_pic(test_d[0])

# %%
show_pic(pred_d[0])

# %%
show_test_pic(mdir, pic_name='test')

# %%
show_test_pic(mdir, pic_name='200')

# %%
# print(test_d[0][100,:])
layer_info0 = get_layer_output(model, test_d[0]/255)
save_layer_output(mdir, 'test0.png', layer_info0)

# layer_info1 = get_layer_output(model, test_d[1]/255)
# save_layer_output(mdir, 'test1.png', layer_info1)

# %%
idx = 20
get_mid_output = K.function([model.layers[0].input],  [model.layers[idx].output])
mid_output = get_mid_output([test_d[0].reshape((1, 512, 512, 1))])

# %%
idx = 20
print(len(layer_info0), len(model.layers)) 
print(layer_info0[idx]['name'])
show_pic(layer_info0[idx]['output'])

# %%
idx = 3
# merged_image_mask = add_colored_mask(test_d_rgb[idx], mask_d_rgb[idx])
merged_image_mask = add_colored_mask(test_d_rgb[idx], pred_d_rgb[idx])
show_pic(merged_image_mask)
